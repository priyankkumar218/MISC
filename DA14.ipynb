# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankkumar218/MISC/blob/master/DA14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GRE Admission Data Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/priyankkumar218/MISC/master/Admission_Predict_Ver1.1.csv')

# %%
dataset.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0           1        337          118  ...  9.65         1              0.92
# 1           2        324          107  ...  8.87         1              0.76
# 2           3        316          104  ...  8.00         1              0.72
# 3           4        322          110  ...  8.67         1              0.80
# 4           5        314          103  ...  8.21         0              0.65
#
# [5 rows x 9 columns]

# %%
dataset.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
desc = dataset.describe()

# %%
desc
# Out:
#        Serial No.   GRE Score  ...    Research  Chance of Admit
# count  500.000000  500.000000  ...  500.000000         500.00000
# mean   250.500000  316.472000  ...    0.560000           0.72174
# std    144.481833   11.295148  ...    0.496884           0.14114
# min      1.000000  290.000000  ...    0.000000           0.34000
# 25%    125.750000  308.000000  ...    0.000000           0.63000
# 50%    250.500000  317.000000  ...    1.000000           0.72000
# 75%    375.250000  325.000000  ...    1.000000           0.82000
# max    500.000000  340.000000  ...    1.000000           0.97000
#
# [8 rows x 9 columns]

# %%
plt.hist(dataset['GRE Score'], bins=100)
plt.show()

# %%
plt.hist(dataset['TOEFL Score'], bins=100)
plt.show()

# %%
plt.hist(dataset['University Rating'], bins=10)
plt.show()

# %%
plt.hist(dataset['SOP'], bins=100)
plt.show()

# %%
plt.hist(dataset['LOR '], bins=100)
plt.show()

# %%
plt.hist(dataset['CGPA'], bins=100)
plt.show()

# %%
plt.hist(dataset['Research'], bins=10)
plt.show()

# %%
plt.hist(dataset['Chance of Admit '], bins=100)
plt.show()

# %%
pd.plotting.scatter_matrix(dataset)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a98041ba8>,
# ...
#       dtype=object)

# %%
corr_mat = dataset.corr()
corr_mat
# Out:
#                    Serial No.  GRE Score  ...  Research  Chance of Admit
# Serial No.           1.000000  -0.103839  ... -0.005332          0.008505
# GRE Score           -0.103839   1.000000  ...  0.563398          0.810351
# TOEFL Score         -0.141696   0.827200  ...  0.467012          0.792228
# University Rating   -0.067641   0.635376  ...  0.427047          0.690132
# SOP                 -0.137352   0.613498  ...  0.408116          0.684137
# LOR                 -0.003694   0.524679  ...  0.372526          0.645365
# CGPA                -0.074289   0.825878  ...  0.501311          0.882413
# Research            -0.005332   0.563398  ...  1.000000          0.545871
# Chance of Admit      0.008505   0.810351  ...  0.545871          1.000000
#
# [9 rows x 9 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(corr_mat, annot=True)

# %%
X = dataset.iloc[:, 1:8].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.score(X, y)
# Out:
# 0.8219007395178417

# %%
sns.boxplot(dataset['Research'], dataset['CGPA'])
